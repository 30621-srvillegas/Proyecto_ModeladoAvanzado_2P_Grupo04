# %% [markdown]
# # Notebook 2: Diagnóstico de Esquemas y Reconstrucción (Bronze)
# **Autor:** MGS. MAGI PAUL DIAZ ZUÑIGA
# **Pipeline ETL - NYC Taxi Trip Records**
# **Objetivo:** Diagnosticar esquemas de archivos fuente, homologar al esquema canónico y escribir la capa Bronze.

# %% [markdown]
# ## Configuración Inicial

# %%
import sys, os, json, logging
from datetime import datetime
from pathlib import Path

# --- AÑADIDO PARA SOLUCIONAR EL ERROR DE PYTHON3 ---
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
# ---------------------------------------------------

sys.path.append(os.path.abspath('..'))
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger('etl')
from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import *
spark = SparkSession.builder \
    .appName("NYC_Taxi_ETL_02") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.sources.partitionOverwriteMode", "dynamic") \
    .config("spark.sql.session.timeZone", "UTC") \
    .master("local[*]") \
    .getOrCreate()
from src.config_loader import *
from src.schema_recovery import diagnose_schema, build_bronze

# %% [markdown]
# ---
# ## FASE 2: Diagnóstico y Reconstrucción de Esquema Canónico
# **Objetivo:** Unificar los esquemas de los 3 servicios (yellow, green, fhvhv) bajo un esquema canónico común.

# %%
# Leer inventario desde la capa audit
inventory_path = os.path.join(METADATA_PATH, "audit_file_inventory")
if os.path.exists(inventory_path):
    df_inv = spark.read.parquet(inventory_path)
    inventory = [row.asDict() for row in df_inv.collect()]
    logger.info(f"Loaded {len(inventory)} inventory records from audit")
else:
    logger.warning("Inventory not found, using sample from raw directories")
    inventory = []
    for svc in SERVICES:
        sp = os.path.join(RAW_PATH, svc)
        if os.path.exists(sp):
            for y in YEARS:
                for m in get_months(y):
                    fp = os.path.join(sp, f"year={y}", f"month={m:02d}", f"{svc}_tripdata_{y}-{m:02d}.parquet")
                    if os.path.exists(fp):
                        try:
                            df = spark.read.parquet(fp)
                            import hashlib
                            inventory.append({
                                "service_type": svc, "file_name": f"{svc}_tripdata_{y}-{m:02d}.parquet",
                                "file_path": fp, "partition_year": y, "partition_month": m,
                                "read_status": "SUCCESS", "record_count": df.count(),
                                "column_count": len(df.columns),
                                "schema_hash": hashlib.md5(str(df.schema).encode()).hexdigest()[:16]
                            })
                        except:
                            pass
    logger.info(f"Built inventory from raw: {len(inventory)} files")
# Out:
# 2026-06-17 17:53:06,634 - etl - INFO - Loaded 84 inventory records from audit

# %%
# Diagnóstico de esquemas
diagnosis = diagnose_schema(spark, inventory)
if diagnosis:
    df_diag = spark.createDataFrame(diagnosis)
    df_diag_pd = df_diag.toPandas()
    print("\nDiagnóstico de esquemas por archivo:")
    display(df_diag_pd)
    # Guardar diagnóstico
    diag_path = os.path.join(METADATA_PATH, "schema_diagnosis")
    df_diag.write.mode("overwrite").parquet(diag_path)
else:
    logger.warning("No diagnosis results")
# Out:
# Diagnóstico de esquemas por archivo:
#    diagnosis_status  expected_columns  \
# 0   MISSING_COLUMNS                19
# 1   MISSING_COLUMNS                19
# 2   MISSING_COLUMNS                19
# 3   MISSING_COLUMNS                19
# 4   MISSING_COLUMNS                19
# ..              ...               ...
# 79  MISSING_COLUMNS                15
# 80  MISSING_COLUMNS                15
# 81  MISSING_COLUMNS                15
# 82  MISSING_COLUMNS                15
# 83  MISSING_COLUMNS                15
#
#                                         extra_columns  \
# 0                   [cbd_congestion_fee, Airport_fee]
# 1                   [cbd_congestion_fee, Airport_fee]
# 2                   [cbd_congestion_fee, Airport_fee]
# 3                   [cbd_congestion_fee, Airport_fee]
# 4                   [cbd_congestion_fee, Airport_fee]
# ..                                                ...
# 79  [bcf, hvfhs_license_num, trip_miles, on_scene_...
# 80  [bcf, hvfhs_license_num, trip_miles, on_scene_...
# 81  [bcf, hvfhs_license_num, trip_miles, on_scene_...
# 82  [bcf, hvfhs_license_num, trip_miles, on_scene_...
# 83  [bcf, hvfhs_license_num, trip_miles, on_scene_...
#
#                           file_name  \
# 0   yellow_tripdata_2025-10.parquet
# 1   yellow_tripdata_2025-11.parquet
# 2   yellow_tripdata_2025-12.parquet
# 3   yellow_tripdata_2026-01.parquet
# 4   yellow_tripdata_2026-02.parquet
# ..                              ...
# 79   fhvhv_tripdata_2025-12.parquet
# 80   fhvhv_tripdata_2026-01.parquet
# 81   fhvhv_tripdata_2026-02.parquet
# 82   fhvhv_tripdata_2026-03.parquet
# 83   fhvhv_tripdata_2026-04.parquet
#
#                                       missing_columns  real_columns  \
# 0                                       [airport_fee]            20
# 1                                       [airport_fee]            20
# 2                                       [airport_fee]            20
# 3                                       [airport_fee]            20
# 4                                       [airport_fee]            20
# ..                                                ...           ...
# 79  [payment_type, trip_distance, RatecodeID, Vend...            25
# 80  [payment_type, trip_distance, RatecodeID, Vend...            25
# 81  [payment_type, trip_distance, RatecodeID, Vend...            25
# 82  [payment_type, trip_distance, RatecodeID, Vend...            25
# 83  [payment_type, trip_distance, RatecodeID, Vend...            25
#
#    service_type
# 0        yellow
# 1        yellow
# 2        yellow
# 3        yellow
# 4        yellow
# ..          ...
# 79        fhvhv
# 80        fhvhv
# 81        fhvhv
# 82        fhvhv
# 83        fhvhv
#
# [84 rows x 7 columns]

# %%
# Construcción de capa Bronze
bronze_records = build_bronze(spark, inventory)
if bronze_records:
    df_bronze_summary = spark.createDataFrame(bronze_records)
    print("\nResumen de carga Bronze:")
    display(df_bronze_summary.toPandas())
    logger.info(f"Bronze layer: {len(bronze_records)} partitions written")
else:
    logger.warning("No bronze records written")
# Out:
# 2026-06-17 17:53:26,550 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2025-10.parquet
# 2026-06-17 17:53:30,173 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2025-11.parquet
# 2026-06-17 17:53:33,849 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2025-12.parquet
# 2026-06-17 17:53:37,019 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2026-01.parquet
# 2026-06-17 17:53:39,831 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2026-02.parquet
# 2026-06-17 17:53:43,465 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2026-03.parquet
# 2026-06-17 17:53:46,638 - src.schema_recovery - INFO - Bronze written: yellow_tripdata_2026-04.parquet
# 2026-06-17 17:53:47,004 - src.schema_recovery - INFO - Bronze written: green_tripdata_2024
- src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-01.parquet
# 2026-06-17 17:55:22,796 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-02.parquet
# 2026-06-17 17:55:34,927 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-03.parquet
# 2026-06-17 17:55:46,608 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-04.parquet
# 2026-06-17 17:55:58,745 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-05.parquet
# 2026-06-17 17:56:10,521 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-06.parquet
# 2026-06-17 17:56:21,590 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-07.parquet
# 2026-06-17 17:56:32,379 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-08.parquet
# 2026-06-17 17:56:44,671 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-09.parquet
# 2026-06-17 17:56:56,175 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-10.parquet
# 2026-06-17 17:57:07,570 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-11.parquet
# 2026-06-17 17:57:19,527 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2024-12.parquet
# 2026-06-17 17:57:31,020 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-01.parquet
# 2026-06-17 17:57:42,791 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-02.parquet
# 2026-06-17 17:57:54,719 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-03.parquet
# 2026-06-17 17:58:06,069 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-04.parquet
# 2026-06-17 17:58:18,118 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-05.parquet
# 2026-06-17 17:58:30,035 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-06.parquet
# 2026-06-17 17:58:40,680 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-07.parquet
# 2026-06-17 17:58:51,161 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-08.parquet
# 2026-06-17 17:59:01,659 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-09.parquet
# 2026-06-17 17:59:14,281 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-10.parquet
# 2026-06-17 17:59:26,600 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-11.parquet
# 2026-06-17 17:59:40,555 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2025-12.parquet
# 2026-06-17 17:59:52,190 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2026-01.parquet
# 2026-06-17 18:00:03,750 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2026-02.parquet
# 2026-06-17 18:00:17,217 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2026-03.parquet
# 2026-06-17 18:00:29,031 - src.schema_recovery - INFO - Bronze written: fhvhv_tripdata_2026-04.parquet
# Resumen de carga Bronze:
#                           file_name  month   records service_type  \
# 0   yellow_tripdata_2025-10.parquet     10   4428699       yellow
# 1   yellow_tripdata_2025-11.parquet     11   4181444       yellow
# 2   yellow_tripdata_2025-12.parquet     12   4305006       yellow
# 3   yellow_tripdata_2026-01.parquet      1   3724889       yellow
# 4   yellow_tripdata_2026-02.parquet      2   3399866       yellow
# ..                              ...    ...       ...          ...
# 79   fhvhv_tripdata_2025-12.parquet     12  22108438        fhvhv
# 80   fhvhv_tripdata_2026-01.parquet      1  20940373        fhvhv
# 81   fhvhv_tripdata_2026-02.parquet      2  19875686        fhvhv
# 82   fhvhv_tripdata_2026-03.parquet      3  22058358        fhvhv
# 83   fhvhv_tripdata_2026-04.parquet      4  20995953        fhvhv
#
#             status  year
# 0   BRONZE_WRITTEN  2025
# 1   BRONZE_WRITTEN  2025
# 2   BRONZE_WRITTEN  2025
# 3   BRONZE_WRITTEN  2026
# 4   BRONZE_WRITTEN  2026
# ..             ...   ...
# 79  BRONZE_WRITTEN  2025
# 80  BRONZE_WRITTEN  2026
# 81  BRONZE_WRITTEN  2026
# 82  BRONZE_WRITTEN  2026
# 83  BRONZE_WRITTEN  2026
#
# [84 rows x 6 columns]
# 2026-06-17 18:00:32,565 - etl - INFO - Bronze layer: 84 partitions written

# %% [markdown]
# ---
# ## Resumen de Diagnóstico y Bronze
# Los archivos se han transformado al esquema canónico y escrito en data/bronze/.
