# %% [markdown]
# # Notebook 1: Extracción e Inventario de Datos
# **Autor:** MGS. MAGI PAUL DIAZ ZUÑIGA
# **Pipeline ETL - NYC Taxi Trip Records**
# **Objetivo:** Descargar archivos Parquet de NYC TLC, generar inventario y procesar archivos corruptos de prueba.

# %% [markdown]
# ## Configuración Inicial
# Importar librerías, crear sesión Spark y definir funciones auxiliares.

# %%
import sys, os, json, hashlib, logging, time
from datetime import datetime
from pathlib import Path

# --- AÑADIDO PARA SOLUCIONAR EL ERROR DE PYTHON3 ---
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
# ---------------------------------------------------

sys.path.append(os.path.abspath('..'))
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger('etl')

from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import *

spark = SparkSession.builder \
    .appName("NYC_Taxi_ETL_01") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.sql.parquet.enableVectorizedReader", "true") \
    .config("spark.sql.sources.partitionOverwriteMode", "dynamic") \
    .config("spark.sql.session.timeZone", "UTC") \
    .master("local[*]") \
    .getOrCreate()

logger.info(f"Spark version: {spark.version}")
# Out:
# 2026-06-17 17:39:52,863 - etl - INFO - Spark version: 4.1.2

# %%
from src.config_loader import *
from src.utils import ensure_dirs, get_headers, generate_process_id, classify_error
from src.extract import download_and_inventory, process_bad_parquet
PROCESS_ID = generate_process_id()
logger.info(f"Process ID: {PROCESS_ID}")
ensure_dirs()
# Out:
# 2026-06-17 17:39:55,507 - etl - INFO - Process ID: f1b9eec0a17b
# 2026-06-17 17:39:55,509 - src.utils - INFO - Directory structure verified

# %% [markdown]
# ---
# ## FASE 1: Extracción de Datos e Inventario
# **Objetivo:** Descargar archivos Parquet desde el repositorio público de NYC TLC y generar un inventario completo con metadatos de cada archivo (tamaño, registros, columnas, hash del esquema).

# %%
inventory = download_and_inventory(spark, SERVICES, YEARS)
df_inventory = spark.createDataFrame(inventory)
inventory_path = os.path.join(METADATA_PATH, "audit_file_inventory")
df_inventory.write.mode("overwrite").parquet(inventory_path)
df_inventory_pd = df_inventory.toPandas()
print(f"\n{'='*80}")
print("  INVENTARIO DE ARCHIVOS")
print(f"{'='*80}")
print(f"Total archivos: {len(inventory)}")
print(f"Exitosos: {sum(1 for i in inventory if i['read_status'] == 'SUCCESS')}")
print(f"Fallidos: {sum(1 for i in inventory if i['read_status'] == 'FAILED')}")
print(f"\nArchivos fallidos:")
for i in inventory:
    if i['read_status'] == 'FAILED':
        print(f"  - {i['file_name']}: {i['error_message'][:100]}")
display(df_inventory_pd)
# Out:
# 2026-06-17 17:40:00,077 - src.extract - INFO - Read yellow_tripdata_2024-01.parquet: 2964624 records, 19 columns
# 2026-06-17 17:40:00,350 - src.extract - INFO - Read yellow_tripdata_2024-02.parquet: 3007526 records, 19 columns
# 2026-06-17 17:40:00,563 - src.extract - INFO - Read yellow_tripdata_2024-03.parquet: 3582628 records, 19 columns
# 2026-06-17 17:40:00,761 - src.extract - INFO - Read yellow_tripdata_2024-04.parquet: 3514289 records, 19 columns
# 2026-06-17 17:40:00,927 - src.extract - INFO - Read yellow_tripdata_2024-05.parquet: 3723833 records, 19 columns
# 2026-06-17 17:40:01,123 - src.extract - INFO - Read yellow_tripdata_2024-06.parquet: 3539193 records, 19 columns
# 2026-06-17 17:40:01,268 - src.extract - INFO - Read yellow_tripdata_2024-07.parquet: 3076903 records, 19 columns
# 2026-06-17 17:40:01,428 - src.extract - INFO - Read yellow_tripdata_2024-08.parquet: 2979183 records, 19 columns
# 2026-06-17 17:40:01,616 - src.extract - INFO - Read yellow_tripdata_2024-09.parquet: 3633030 records, 19 columns
# 2026-06-17 17:40:01,774 - src.extract - INFO - Read yellow_tripdata_2024-10.parquet: 3833771 records, 19 columns
# 2026-06-17 17:40:01,904 - src.extract - INFO - Read yellow_tripdata_2024-11.parquet: 3646369 records, 19 columns
# 2026-06-17 17:40:02,044 - src.extract - INFO - Read yellow_tripdata_2024-12.parquet: 3668371 records, 19 columns
# 2026-06-17 17:40:02,174 - src.extract - INFO - Read yellow_tripdata_2025-01.parquet: 3475226 records, 20 columns
# 2026-06-17 17:40:02,285 - src.extract - INFO - Read yellow_tripdata_2025-02.parquet: 3577543 records, 20 columns
# 2026-06-17 17:40:02,405 - src.extract - INFO - Read yellow_tripdata_2025-03.parquet: 4145257 records, 20 columns
# 2026-06-17 17:40:02,547 - src.extract - INFO - Read yellow_tripdata_2025-04.parquet: 3970553 records, 20 columns
# 2026-06-17 17:40:02,695 - src.extract - INFO - Read yellow_tripdata_2025-05.parquet: 4591845 records, 20 columns
# 2026-06-17 17:40:02,831 - src.extract - INFO - Read yellow_tripdata_2025-06.parquet: 4322960 records, 20 columns
# 2026-06-17 17:40:02,959 - src.extract - INFO - Read yellow_tripdata_2025-07.parquet: 3898963 records, 20 columns
# 2026-06-17 17:40:03,060 - src.extract - INFO - Read yellow_tripdata_2025-08.parquet: 3574091 records, 20 columns
# 2026-06-17 17:40:03,163 - src.extract - INFO - Read yellow_tripdata_2025-09.parquet: 4251015 records, 20 columns
# 2026-06-17 17:40:03,267 - src.extract - INFO - Read yellow_tripdata_2025-10.parquet: 4428699 records, 20 columns
# 2026-06-17 17:40:03,385 - src.extract - INFO - Read yellow_tripdata_2025-11.parquet: 4181444 records, 20 columns
# 2026-06-17 17:40:03,502 - src.extract - INFO - Read yellow_tripdata_2025-12.parquet: 4305006 records, 20 columns
# 2026-06-17 17:40:03,607 - src.extract - INFO - Read yellow_tripdata_2026-01.parquet: 3724889 records, 20 columns
# 2026-06-17 17:40:03,729 - src.extract - INFO - Read yellow_tripdata_2026-02.parquet: 3399866 records, 20 columns
# 2026-06-17 17:40:03,822 - src.extract - INFO - Read yellow_tripdata_2026-03.parquet: 3952451 records, 20 columns
# 2026-06-17 17:40:03,935 - src.extract - INFO - Read yellow_tripdata_2026-04.parquet: 3831240 records, 20 columns
# 2026-06-17 17:40:04,026 - src.extract - INFO - Read green_tripdata_2024-01.parquet: 56551 records, 20 columns
# 2026-06-17 17:40:04,119 - src.extract - INFO - Read green_tripdata_2024-02.parquet: 53577 records, 20 columns
# 2026-06-17 17:40:04,207 - src.extract - INFO - Read green_tripdata_2024-03.parquet: 57457 records, 20 columns
# 2026-06-17 17:40:04,289 - src.extract - INFO - Read green_tripdata_2024-04.parquet: 56471 records, 20 columns
# 2026-06-17 17:40:04,378 - src.extract - INFO - Read green_tripdata_2024-05.parquet: 61003 records, 20 columns
# 2026-06-17 17:40:04,483 - src.extract - INFO - Read green_tripdata_2024-06.parquet: 54748 records, 20 columns
# 2026-06-17 17:40:04,608 - src.extract - INFO - Read green_tripdata_2024-07.parquet: 51837 records, 20 columns
# 2026-06-17 17:40:04,692 - src.extract - INFO - Read green_tripdata_2024-08.parquet: 51771 records, 20 columns
# 2026-06-17 17:40:04,789 - src.extract - INFO - Read green_tripdata_2024-09.parquet: 54440 records, 20 columns
# 2026-06-17 17:40:04,870 - src.extract - INFO - Read green_tripdata_2024-10.parquet: 56147 records, 20 columns
# 2026-06-17 17:40:04,949 - src.extract - INFO - Read green_tripdata_2024-11.parquet: 52222 records, 20 columns
# 2026-06-17 17:40:05,027 - src.extract - INFO - Read green_tripdata_2024-12.parquet: 53994 records, 20 columns
# 2026-06-17 17:40:05,109 - src.extract - INFO - Read green_tripdata_2025-01.parquet: 48326 records, 21 columns
# 2026-06-17 17:40:05,190 - src.extract - INFO - Read green_tripdata_2025-02.parquet: 46621 records, 21 columns
# 2026-06-17 17:40:05,270 - src.extract - INFO - Read green_tripdata_2025-03.parquet: 51539 records, 21 columns
# 2026-06-17 17:40:05,346 - src.extract - INFO - Read green_tripdata_2025-04.parquet: 52132 records, 21 columns
# 2026-06-17 17:40:05,445 - src.extract - INFO - Read green_tripdata_2025-05.parquet: 55399 records, 21 columns
# 2026-06-17 17:40:05,531 - src.extract - INFO - Read green_tripdata_2025-06.parquet: 49390 records, 21 columns
# 2026-06-17 17:40:05,617 - src.extract - INFO - Read green_tripdata_2025-07.parquet: 48205 records, 21 columns
# 2026-06-17 17:40:05,704 - src.extract - INFO - Read green_tripdata_2025-08.parquet: 46306 records, 21 columns
# 2026-06-17 17:40:05,802 - src.extract - INFO - Read green_tripdata_2025-09.parquet: 48893 records, 21 columns
# 2026-06-17 17:40:05,881 - src.extract - INFO - Read green_tripdata_2025-10.parquet: 49416 records, 21 columns
# 2026-06-17 17:40:05,958 - src.extract - INFO - Read green_tripdata_2025-11.parquet: 46912 records, 21 columns
# 2026-06-17 17:40:06,041 - src.extract - INFO - Read green_tripdata_2025-12.parquet: 48236 records, 21 columns
# 2026-06-17 17:40:06,122 - src.extract - INFO - Read green_tripdata_2026-01.parquet: 40272 records, 21 columns
# 2026-06-17 17:40:06,202 - src.extract - INFO - Read green_tripdata_2026-02.parquet: 37373 records, 21 columns
# 2026-06-17 17:40:06,281 - src.extract - INFO - Read green_tripdata_2026-03.parquet: 44208 records, 21 columns
# 2026-06-17 17:40:06,364 - src.extract - INFO - Read green_tripdata_2026-04.parquet: 44238 records, 21 columns
# 2026-06-17 17:40:06,482 - src.extract - INFO - Read fhvhv_tripdata_2024-01.parquet: 19663930 records, 24 columns
# 2026-06-17 17:40:06,592 - src.extract - INFO - Read fhvhv_tripdata_2024-02.parquet: 19359148 records, 24 columns
# 2026-06-17 17:40:06,695 - src.extract - INFO - Read fhvhv_tripdata_2024-03.parquet: 21280788 records, 24 columns
# 2026-06-17 17:40:06,790 - src.extract - INFO - Read fhvhv_tripdata_2024-04.parquet: 19733038 records, 24 columns
# 2026-06-17 17:40:06,894 - src.extract - INFO - Read fhvhv_tripdata_2024-05.parquet: 20704538 records, 24 columns
# 2026-06-17 17:40:06,998 - src.extract - INFO - Read fhvhv_tripdata_2024-06.parquet: 20123226 records, 24 columns
# 2026-06-17 17:40:07,098 - src.extract - INFO - Read fhvhv_tripdata_2024-07.parquet: 19182934 records, 24 columns
# 2026-06-17 17:40:07,209 - src.extract - INFO - Read fhvhv_tripdata_2024-08.parquet: 19128392 records, 24 columns
# 2026-06-17 17:40:07,307 - src.extract - INFO - Read fhvhv_tripdata_2024-09.parquet: 19209788 records, 24 columns
# 2026-06-17 17:40:07,393 - src.extract - INFO - Read fhvhv_tripdata_2024-10.parquet: 20028282 records, 24 columns
# 2026-06-17 17:40:07,498 - src.extract - INFO - Read fhvhv_tripdata_2024-11.parquet: 19987533 records, 24 columns
# 2026-06-17 17:40:07,591 - src.extract - INFO - Read fhvhv_tripdata_2024-12.parquet: 21068851 records, 24 columns
# 2026-06-17 17:40:07,679 - src.extract - INFO - Read fhvhv_tripdata_2025-01.parquet: 20405666 records, 25 columns
# 2026-06-17 17:40:07,783 - src.extract - INFO - Read fhvhv_tripdata_2025-02.parquet: 19339461 records, 25 columns
# 2026-06-17 17:40:07,883 - src.extract - INFO - Read fhvhv_tripdata_2025-03.parquet: 20536879 records, 25 columns
# 2026-06-17 17:40:07,972 - src.extract - INFO - Read fhvhv_tripdata_2025-04.parquet: 19753983 records, 25 columns
# 2026-06-17 17:40:08,056 - src.extract - INFO - Read fhvhv_tripdata_2025-05.parquet: 21091193 records, 25 columns
# 2026-06-17 17:40:08,149 - src.extract - INFO - Read fhvhv_tripdata_2025-06.parquet: 19868009 records, 25 columns
# 2026-06-17 17:40:08,234 - src.extract - INFO - Read fhvhv_tripdata_2025-07.parquet: 19653012 records, 25 columns
# 2026-06-17 17:40:08,323 - src.extract - INFO - Read fhvhv_tripdata_2025-08.parquet: 19271461 records, 25 columns
# 2026-06-17 17:40:08,422 - src.extract - INFO - Read fhvhv_tripdata_2025-09.parquet: 19434641 records, 25 columns
# 2026-06-17 17:40:08,512 - src.extract - INFO - Read fhvhv_tripdata_2025-10.parquet: 21308701 records, 25 columns
# 2026-06-17 17:40:08,600 - src.extract - INFO - Read fhvhv_tripdata_2025-11.parquet: 20818240 records, 25 columns
# 2026-06-17 17:40:08,697 - src.extract - INFO - Read fhvhv_tripdata_2025-12.parquet: 22108438 records, 25 columns
# 2026-06-17 17:40:08,826 - src.extract - INFO - Read fhvhv_tripdata_2026-01.parquet: 20940373 records, 25 columns
# 2026-06-17 17:40:08,919 - src.extract - INFO - Read fhvhv_tripdata_2026-02.parquet: 19875686 records, 25 columns
# 2026-06-17 17:40:09,025 - src.extract - INFO - Read fhvhv_tripdata_2026-03.parquet: 22058358 records, 25 columns
# 2026-06-17 17:40:09,123 - src.extract - INFO - Read fhvhv_tripdata_2026-04.parquet: 20995953 records, 25 columns
# 2026-06-17 17:40:09,123 - src.extract - INFO - Inventory: 84 files, 84 successful, 0 failed
# ================================================================================
#   INVENTARIO DE ARCHIVOS
# ================================================================================
# Total archivos: 84
# Exitosos: 84
# Fallidos: 0
#
# Archivos fallidos:
#     column_count error_message                        file_name  \
# 0             19                yellow_tripdata_2024-01.parquet
# 1             19                yellow_tripdata_2024-02.parquet
# 2             19                yellow_tripdata_2024-03.parquet
# 3             19                yellow_tripdata_2024-04.parquet
# 4             19                yellow_tripdata_2024-05.parquet
# ..           ...           ...                              ...
# 79            25                 fhvhv_tripdata_2025-12.parquet
# 80            25                 fhvhv_tripdata_2026-01.parquet
# 81            25                 fhvhv_tripdata_2026-02.parquet
# 82            25                 fhvhv_tripdata_2026-03.parquet
# 83            25                 fhvhv_tripdata_2026-04.parquet
#
#                                             file_path  file_size_mb  \
# 0   C:\Users\G300\Downloads\proyecto\Proyecto ETL\...         47.65
# 1   C:\Users\G300\Downloads\proyecto\Proyecto ETL\...         48.02
# 2   C:\Users\G300\Downloads\proyecto\Proyecto ETL\...         57.30
# 3   C:\Users\G300\Downloads\proyecto\Proyecto ETL\...         56.39
# 4   C:\Users\G300\Downloads\proyecto\Proyecto ETL\...         59.66
# ..                                                ...           ...
# 79  C:\Users\G300\Downloads\proyecto\Proyecto ETL\...        510.94
# 80  C:\Users\G300\Downloads\proyecto\Proyecto ETL\...        482.43
# 81  C:\Users\G300\Downloads\proyecto\Proyecto ETL\...        454.69
# 82  C:\Users\G300\Downloads\proyecto\Proyecto ETL\...        507.94
# 83  C:\Users\G300\Downloads\proyecto\Proyecto ETL\...        486.25
#
#     partition_month  partition_year process_id                processed_at  \
# 0                 1            2024             2026-06-17T17:40:00.077527
# 1                 2            2024             2026-06-17T17:40:00.350735
# 2                 3            2024             2026-06-17T17:40:00.563503
# 3                 4            2024             2026-06-17T17:40:00.761682
# 4                 5            2024             2026-06-17T17:40:00.927326
# ..              ...             ...        ...                         ...
# 79               12            2025             2026-06-17T17:40:08.697639
# 80                1            2026             2026-06-17T17:40:08.826791
# 81                2            2026             2026-06-17T17:40:08.919325
# 82                3            2026             2026-06-17T17:40:09.025359
# 83                4            2026             2026-06-17T17:40:09.123160
#
#    read_status  record_count       schema_hash service_type source_system
# 0      SUCCESS       2964624  6069aa5f0abcb1a9       yellow       NYC_TLC
# 1      SUCCESS       3007526  6069aa5f0abcb1a9       yellow       NYC_TLC
# 2      SUCCESS       3582628  6069aa5f0abcb1a9       yellow       NYC_TLC
# 3      SUCCESS       3514289  6069aa5f0abcb1a9       yellow       NYC_TLC
# 4      SUCCESS       3723833  6069aa5f0abcb1a9       yellow       NYC_TLC
# ..         ...           ...               ...          ...           ...
# 79     SUCCESS      22108438  51fcf4d8a7a50836        fhvhv       NYC_TLC
# 80     SUCCESS      20940373  51fcf4d8a7a50836        fhvhv       NYC_TLC
# 81     SUCCESS      19875686  51fcf4d8a7a50836        fhvhv       NYC_TLC
# 82     SUCCESS      22058358  51fcf4d8a7a50836        fhvhv       NYC_TLC
# 83     SUCCESS      20995953  51fcf4d8a7a50836        fhvhv       NYC_TLC
#
# [84 rows x 14 columns]

# %% [markdown]
# ---
# ## FASE 1b: Procesamiento de Archivos Parquet Dañados (bad_parquet)
# **Objetivo:** Demostrar la detección y clasificación de archivos corruptos desde el repositorio de pruebas.

# %%
bad_inventory, bad_quarantine = process_bad_parquet(spark)
if bad_quarantine:
    df_bad_q = spark.createDataFrame(bad_quarantine)
    logger.info(f"Bad parquet quarantine: {len(bad_quarantine)} records")
    df_bad_q.show(truncate=False)
    df_bad_q.write.mode("append").parquet(os.path.join(QUARANTINE_PATH, "quarantine_log"))
    if bad_inventory:
        bad_inv_pd = spark.createDataFrame(bad_inventory).toPandas()
        logger.info(f"Bad parquet files processed: {len(bad_inventory)}")
else:
    logger.info("No bad_parquet files to process")
# Out:
# 2026-06-17 17:40:16,424 - src.extract - WARNING - Bad parquet bad_magic_number.parquet failed as expected: An error occurred while calling o485.parquet.
# : org.apache.spark.SparkException: Job aborted due to
# 2026-06-17 17:40:16,538 - src.extract - WARNING - Bad parquet corrupt_metadata.parquet failed as expected: An error occurred while calling o496.parquet.
# : org.apache.spark.SparkException: Job aborted due to
# 2026-06-17 17:40:16,634 - src.extract - WARNING - Bad parquet empty.parquet failed as expected: An error occurred while calling o507.parquet.
# : org.apache.spark.SparkException: Job aborted due to
# 2026-06-17 17:40:16,717 - src.extract - WARNING - Bad parquet unsupported_format.parquet failed as expected: An error occurred while calling o518.parquet.
# : org.apache.spark.SparkException: Job aborted due to
# 2026-06-17 17:40:16,730 - etl - INFO - Bad parquet quarantine: 4 records
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+--------------------------+-----------------------+---------------------+------------+----------------+
# |error_message                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |file_name                 |process_id|quarantined_at            |recommended_action     |rejection_category   |service_type|stage           |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+--------------------------+-----------------------+---------------------+------------+----------------+
# |An error occurred while calling o485.parquet.\n: org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 338.0 failed 1 times, most recent failure: Lost task 0.0 in stage 338.0 (TID 428) (G406M14.mshome.net executor driver): org.apache.spark.SparkException: Exception thrown in awaitResult: \r\n\tat org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)\r\n\tat org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:359)\r\n\tat org.apache.spark.u|bad_magic_number.parquet  |          |2026-06-17T17:40:16.425236|Attempt schema recovery|PARTIALLY_RECOVERABLE|bad_parquet |bad_parquet_test|
# |An error occurred while calling o496.parquet.\n: org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 339.0 failed 1 times, most recent failure: Lost task 0.0 in stage 339.0 (TID 429) (G406M14.mshome.net executor driver): org.apache.spark.SparkException: Exception thrown in awaitResult: \r\n\tat org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)\r\n\tat org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:359)\r\n\tat org.apache.spark.u|corrupt_metadata.parquet  |          |2026-06-17T17:40:16.539501|Attempt schema recovery|PARTIALLY_RECOVERABLE|bad_parquet |bad_parquet_test|
# |An error occurred while calling o507.parquet.\n: org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 340.0 failed 1 times, most recent failure: Lost task 0.0 in stage 340.0 (TID 430) (G406M14.mshome.net executor driver): org.apache.spark.SparkException: Exception thrown in awaitResult: \r\n\tat org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)\r\n\tat org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:359)\r\n\tat org.apache.spark.u|empty.parquet             |          |2026-06-17T17:40:16.634714|Attempt schema recovery|PARTIALLY_RECOVERABLE|bad_parquet |bad_parquet_test|
# |An error occurred while calling o518.parquet.\n: org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 341.0 failed 1 times, most recent failure: Lost task 0.0 in stage 341.0 (TID 431) (G406M14.mshome.net executor driver): org.apache.spark.SparkException: Exception thrown in awaitResult: \r\n\tat org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:53)\r\n\tat org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:359)\r\n\tat org.apache.spark.u|unsupported_format.parquet|          |2026-06-17T17:40:16.718380|Attempt schema recovery|PARTIALLY_RECOVERABLE|bad_parquet |bad_parquet_test|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+----------+--------------------------+-----------------------+---------------------+------------+----------------+
# 2026-06-17 17:40:26,797 - etl - INFO - Bad parquet files processed: 4

# %% [markdown]
# ---
# ## Resumen de Extracción
# Pipeline completado. Los archivos se encuentran en data/raw/ y el inventario en data/audit/audit_file_inventory/.
